# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_Introduction_a_la_programmation_python_ (1).ipynb',
#  '01_Introduction_a_la_programmation_python_.ipynb',
#  '1._Introduction_a_Python_-_Empty_1.ipynb',
#  '11._Python_-_Fonctions_-_Corrige_apprenants.ipynb',
#  '11._Python_-_Fonctions_-_Empty.ipynb',
#  '12. Probabilités - Sets et Venn - corrigé(2).ipynb',
#  '13._Proba__Stats_-_Topic_3_-_Corrige_temp (1).ipynb',
#  '13._Proba__Stats_-_Topic_3_-_Corrige_temp.ipynb',
#  '13._Proba__Stats_-_Topic_3_-_Empty.ipynb',
#  '14._Proba__Stats_-_Topic_4_-_Corrige_apprenants.ipynb',
#  '14._Proba__Stats_-_Topic_4_-_Empty.ipynb',
#  '15. Python - Algorithmie - Corrigé Apprenants.ipynb',
#  '15._Python_-_Algorithmie_-_L.Sanne.ipynb',
#  '16._Python_-_Set__Dictionnaires_-_Empty.ipynb',
#  '17. Probabilités - Evènements - corrigé.ipynb',
#  '19. Python - Révisions- Corrigé apprenants.ipynb',
#  '19. Python - Révisions- Ludovic Sanne.ipynb',
#  '2._Python_-_Tuples__Listes_-_Empty_.ipynb',
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

# %%
user = ""
pwd = ""
driver = webdriver.Firefox()
driver.get("https://www.bellesdemeures.com/annonces/vente/tt-2-tb-1-pl-48514/158579797/#?cmp=INTSL_ListToDetail")

# %%
html= """
<html>
 
 <header class="header ">
    <div class="headerWrapper">
        <span class="headerBurger"><span></span></span>
        <a class="headerLogo" href="https://www.bellesdemeures.com:443/" title="Belles Demeures Finest properties only.">
        <div class="detailBannerInfos">

   <div class="detailBannerInfos">

    <div class="detailBannerInfosWrap">

        <h1 class="title">
            <span class="detailBannerInfosTypeBien">Appartement</span>
            <div class="annonceSpecs">
                <ul class="annonceSpecsList">
                    <li class="annonceSpecsListItem js_nbRooms">
                        2 <span>Pièces</span>
                    </li>

                    <li class="annonceSpecsListItem">
                        <span class="separator">•</span>
                        1 <span>Chambre</span>
                    </li>
                                        <li class="annonceSpecsListItem js_livingArea">
                        <span class="separator">•</span>
                        46 <span>M²</span>
                    </li>
                </ul>
            </div>
            <div class="wrap">
                <span class="js_locality">Paris 16ème</span>
                <div class="itemMap js_mapScroll trackClick btnDisp" data-tracking-type="utilisationOutil" data-tracking-datas="Detail_Carte">
                    <div class="itemMapBtnLink">
                        <span class="longLabel">
                            Voir sur la carte
                        </span>
                    </div>
                </div>
            </div>

            <span class="js_price">785&nbsp;000 €</span>
            <div class="itemMap js_mapScroll trackClick itemMapMobile btnDisp" data-tracking-type="utilisationOutil" data-tracking-datas="Detail_Carte">
                <div class="itemMapBtnLink">
                    <span class="longLabel">
                        Voir sur la carte
                    </span>
                </div>
            </div>
        </h1>

    </div><!-- fin detailBannerInfosWrap -->

</div>

<div class="carouselListItemCenter js_carouselLayerClick carouselLayerClick js_btn" 
   style="width: 859px; height: 645px;"></div>
    <div title="Terrasse" class="detailInfosListBestPicto terrasse"></div>
    <div title="Balcon" class="detailInfosListBestPicto balcon"></div>
    <div title="Ascenseur" class="detailInfosListBestPicto ascenseur"></div>
    <div title="Cave" class="detailInfosListBestPicto cave"></div>
 <li>2 Pièces</li>
 <p class="detailMoreAlur">
        785&nbsp;000 € <br>
Les honoraires TTC sont inclus à la charge de l’acquéreur, soit 3,29% du prix du bien<br>
    </p>
  </body>

</html>
# Out:
#   File "<ipython-input-8-35827bf385ab>", line 70
#     </html>
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
input_searche_s = driver.find_element_by_class_name('annonceSpecsListItem js_nbRooms')
input_searche_s
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-9-97d997e8eeea> in <module>
# ----> 1 input_searche_s = driver.find_element_by_class_name('annonceSpecsListItem js_nbRooms')
#       2 input_searche_s
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ...
